# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
'''
Your Code
'''
import requests

r = requests.get('https://api.github.com/events') #爬資料的目標網址
r.text #模擬發送請求
# Out:
# '[{"id":"10966214562","type":"PushEvent","actor":{"id":29817768,"login":"lanlan2017","display_login":"lanlan2017","gravatar_id":"","url":"https://api.github.com/users/lanlan2017","avatar_url":"https://avatars.githubusercontent.com/u/29817768?"},"repo":{"id":219454408,"name":"lanlan2017/blog","url":"https://api.github.com/repos/lanlan2017/blog"},"payload":{"push_id":4330537842,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"e89f09478bc0341212fa6b84e4e6eb80a4d4456a","before":"72ba52bc4fced0566dff17cd717eda7b1892e540","commits":[{"sha":"e89f09478bc0341212fa6b84e4e6eb80a4d4456a","author":{"email":"18251956727@163.com","name":"lanlan2017"},"message":"添加新的文章,更新文章","distinct":true,"url":"https://api.github.com/repos/lanlan2017/blog/commits/e89f09478bc0341212fa6b84e4e6eb80a4d4456a"}]},"public":true,"created_at":"2019-11-28T06:16:10Z"},{"id":"10966214557","type":"PullRequestEvent","actor":{"id":3771933,"login":"zhangsanshi","display_login":"zhangsanshi","gravatar_id":"","url":"ht
# ...

# %% [markdown]
# # json

# %%
import json

json.loads(r.text) #模擬發送請求
# Out:
# [{'id': '10966208906',
#   'type': 'PushEvent',
#   'actor': {'id': 2510184,
#    'login': 'navidshaikh',
#    'display_login': 'navidshaikh',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/navidshaikh',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2510184?'},
#   'repo': {'id': 171464939,
#    'name': 'navidshaikh/client',
#    'url': 'https://api.github.com/repos/navidshaikh/client'},
#   'payload': {'push_id': 4330534778,
#    'size': 8,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '0efde628cb88ff4162978a6558ea1883a1723e0e',
#    'before': '764e8c933efa8fcbf3b458cc46635cc1e79ab8ec',
#    'commits': [{'sha': 'd116fb94225488c8c0b44e609e6ae95364975093',
#      'author': {'email': 'guoyingc@cn.ibm.com', 'name': 'Ying Chun Guo'},
#      'message': 'shorten the --log-http Authorization mask value (#484)',
#      'distinct': False,
# ...

# %% [markdown]
# Ans:
#
# r.text所發送出來的請求為字串(str)的型態，json所發送出來的請求為字典(dict)的型態

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
'''
Your Code
'''
import requests

r = requests.get('https://cat-fact.herokuapp.com/facts ') #爬資料的目標網址
r.text #模擬發送請求
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n<head>\n<meta charset="utf-8">\n<title>Error</title>\n</head>\n<body>\n<pre>Cannot GET /facts%20</pre>\n</body>\n</html>\n'

# %%
#get方法
import json
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get("https://cat-fact.herokuapp.com/facts", params=payload)
json.loads(r.text)
# Out:
# {'all': [{'_id': '5b4911940508220014ccfe94',
#    'text': 'By the time a cat is 9 years old, it will only have been awake for three years of its life.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '58e008ad0aac31001185ed0c',
#    'text': "The frequency of a domestic cat's purr is the same at which muscles and bones repair themselves.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '5955792c7b77520020799431',
#    'text': 'Cats "knead" because of seperation from their mothers',
#    'type': 'cat',
#    'user': {'_id': '595579027b77520020799430',
#     'name': {'first': 'Is It Still Memes That', 'last': 'Make You Sweat?'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '59a60b8e6acf530020f3586e',
# ...
